# %%
class Human:
  def __init__(self):
    self.name = 'Yamada Taro'
    self.age = 28

  def show_info(self):
    print(self.name)
    print(self.age)

person = Human()
person.show_info()
# Out:
# Yamada Taro
# 28
