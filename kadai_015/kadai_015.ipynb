# %%
class Human:
  def __init__(self):
    self.name = 'Yamada Taro'
    self.age = 28

  def printinfo(self):
    print(self.name)
    print(self.age)

person = Human()
person.printinfo()
# Out:
# Yamada Taro
# 28
